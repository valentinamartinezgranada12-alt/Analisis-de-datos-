# %% [markdown]
# PRIMER PARCIAL

# %%
import pandas as pd
import numpy as np

# %%
#caracteristicas generales, seguridad social en salud y educación 

#links a los conjuntos de datos: 
url_cgsse = 'https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/refs/heads/main/Datos/GEIH2025/cgsse.CSV'
url_ocupados = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
url_ft = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV' 
url_desocupados = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV'

# CGSSE
df_cgsse = pd.read_csv(url_cgsse, encoding='latin-1', sep=';', 
                       low_memory=False)

#Ocupados
df_ocupados=pd.read_csv(url_ocupados,encoding='latin-1',sep=';',
                        low_memory=False)

#Fuerza de trabajo
df_ft=pd.read_csv(url_ft,
                  encoding='latin-1',sep=';',low_memory=False)
#No ocupados
df_d=pd.read_csv(url_desocupados,encoding='latin-1',
                           sep=';',low_memory=False)

# %%
poblacion_total = df_cgsse['FEX_C18'].sum()
print(f' POBLACIÓN TOTAL DE COLOMBIA : {poblacion_total}')
# Out:
#  POBLACIÓN TOTAL DE COLOMBIA : 52045001.000009045

# %%
#Leyendo los datos de la geih
df_cgsse = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/cgsse.CSV'
                       ,encoding='latin',sep=';'
                       )

df_o = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
                       ,encoding='latin',sep=';'
                       )

df_d = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV'
                       ,encoding='latin',sep=';'
                       )
df_ft = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'
                       ,encoding='latin',sep=';'
                       )
# Out:
# /tmp/ipykernel_35120/3175422324.py:6: DtypeWarning: Columns (0: P6430S1, 1: P6765S1, 2: P6780S1, 3: P6915S1, 4: P7028S1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_o = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
# /tmp/ipykernel_35120/3175422324.py:13: DtypeWarning: Columns (0: P3362S7A1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ft = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'

# %%
#Primero hay que anexar la p3271 a la tabla de desempleados
df_d = pd.merge(df_d, df_cgsse[['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'P3271','P6040']], 
                        on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how='left')

df_ft = pd.merge(df_ft, df_cgsse[['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'P3271','P6040']], 
                        on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how='left')

# %%
# 1. Calcular cantidad de hombres desempleados en el quindío 
HDQ = df_d[(df_d['DSI']==1) & (df_d['DPTO']==63) & (df_d['P3271']==1)]['FEX_C18'].sum()
print(f'Hombres Desempleados en el Quindio: {HDQ}')

# 2. Calcular cantidad de hombres en la PEA del quindío
PEAHQ = df_ft[(df_ft['FT']==1) & (df_ft['DPTO']==63) & (df_ft['P3271']==1) ]['FEX_C18'].sum()
print(f'Poblacion Economicamente Activa de hombres en el quindío: {PEAHQ}')

# %%
#PREGUNTA 8: CALCULAR LAS PERSONAS DESEMPLEADAS EN EL QUINDIO ENTRE LOS 18 Y 30 AÑOS  
dqpe = df_d[(df_d['DSI']==1) & (df_d['P6040']>=18) & (df_d['P6040']<=30) & (df_d['DPTO']==63)]['FEX_C18'].sum()
print(f'Personas Desempleadas en el quindío entre los 18 - 30 años: {dqpe}')
# Out:
# Personas Desempleadas en el quindío entre los 18 - 30 años: 9479.632579867999
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
# POTE = PERSONAS OCUPADAS EN EL TOLIMA POR EDAD: 
pote = df_o[ (df_o) & (df_d['P6040']>=20) & (df_d['P6040']<=25) & (df_d['DPTO']==73)]['FEX_C18'].sum()
